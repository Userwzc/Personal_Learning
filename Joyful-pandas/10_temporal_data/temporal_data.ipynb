# %% [markdown]
# ### 第十章 时序数据

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 一、时序中的基本对象
# 时间序列的概念在日常生活中十分常见，但对于一个具体的时序事件而言，可以从多个时间对象的角度来描述。
# 概念         |  单元素类型  |     数组类型      | pandas数据类型
# Data times     Timestamp   DatatimeIndex      datatime64[ns]
# Time deltas    Timedelta   TimedeltaIndex     timedelta64[ns]
# Time spans     Period      PeriodIndex        period[freq]
# Data offsets   DateOffset  None               None

# %% [markdown]
# #### 时间戳
# ##### 1.Timestamp的构造与属性
# 单个时间戳的生成利用`pd.Timestamp`实现，一般而言的常见日期格式都能被成功地转换:

# %%
ts = pd.Timestamp('2020/1/1')
ts
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
ts = pd.Timestamp('2020-1-1 08:10:30')
ts
# Out:
# Timestamp('2020-01-01 08:10:30')

# %% [markdown]
# 通过`year, month, day, hour, min, second`可以获取具体的数值:

# %%
ts.year
# Out:
# 2020

# %%
ts.month
# Out:
# 1

# %%
ts.day
# Out:
# 1

# %%
ts.hour
# Out:
# 8

# %%
ts.minute
# Out:
# 10

# %%
ts.second
# Out:
# 30

# %% [markdown]
# 在`pandas`中，时间戳的最小精度为纳秒`ns`，由于使用了64位存储，可以表示的时间范围大约585年
# 通过`pd.Timestamp.max`和`pd.Timestamp.min`可以获取时间戳表示的范围，可以看到确实表示的区间年数大小正如上述计算结果:

# %%
pd.Timestamp.max
# Out:
# Timestamp('2262-04-11 23:47:16.854775807')

# %%
pd.Timestamp.min
# Out:
# Timestamp('1677-09-21 00:12:43.145224193')

# %%
pd.Timestamp.max.year - pd.Timestamp.min.year
# Out:
# 585

# %% [markdown]
# ##### 2.Datatime序列的生成
# 一组时间戳可以组成时间序列，可以用`to_datetime`和`date_range`来生成。其中，`to_datetime`能够把一列时间戳格式的对象转换为datetime64[ns]类型的时间序列:

# %%
pd.to_datetime(['2020-1-1','2020-1-3','2020-1-6'])
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-03', '2020-01-06'], dtype='datetime64[ns]', freq=None)

# %%
df = pd.read_csv('../pandas_basis/learn_pandas.csv')
s = pd.to_datetime(df.Test_Date)
s.head()
# Out:
# 0   2019-10-05
# 1   2019-09-04
# 2   2019-09-12
# 3   2020-01-03
# 4   2019-11-06
# Name: Test_Date, dtype: datetime64[ns]

# %% [markdown]
# 在极少数情况下，时间戳的格式不满足转换时，可以强制使用`format`进行匹配:

# %%
temp = pd.to_datetime(['2020\\1\\1','2020\\1\\3'], format = '%Y\\%m\\%d')
temp
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-03'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# 注意上面由于传入的是列表，而非`pandas`内部的`Series`，因此返回的是`DatetimeIndex`，如果想要转为`datetime64[ns]`的序列，需要显式用`Series`转化:

# %%
pd.Series(temp).head()
# Out:
# 0   2020-01-01
# 1   2020-01-03
# dtype: datetime64[ns]

# %% [markdown]
# 另外，还存在一种把表的多列时间属性拼接转为时间序列的`to_datetime`操作，此时的列名必须和以下给定的时间关键词列名一致:

# %%
df_date_cols = pd.DataFrame({'year':[2020,2020],
                             'month':[1,1],
                             'day':[1,2],
                             'hour':[10,20],
                             'minute':[30,50],
                             'second':[20,40]})
pd.to_datetime(df_date_cols)
# Out:
# 0   2020-01-01 10:30:20
# 1   2020-01-02 20:50:40
# dtype: datetime64[ns]

# %% [markdown]
# `date_range`是一种生成连续间隔时间的一种方法，其重要的参数为`start, end, freq, periods`,它们分别表示开始时间，结束时间，时间间隔，时间戳个数。其中，四个中的三个参数决定了，那么剩下的一个就随之确定了。这里要注意，开始或结束日期如果作为端点则它会被包含:

# %%
pd.date_range('2020-1-1','2020-1-21', freq = '10D') # 包含
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-11', '2020-01-21'], dtype='datetime64[ns]', freq='10D')

# %%
pd.date_range('2020-1-1','2020-2-28', freq = '10D')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-11', '2020-01-21', '2020-01-31',
#                '2020-02-10', '2020-02-20'],
#               dtype='datetime64[ns]', freq='10D')

# %%
pd.date_range('2020-1-1','2020-2-28', periods = 6) # 由于结束日期无法取到，freq不为10天
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-12 14:24:00',
#                '2020-01-24 04:48:00', '2020-02-04 19:12:00',
#                '2020-02-16 09:36:00', '2020-02-28 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# 这里`freq`参数与`DateOffset`对象紧密相关，将在第四节介绍其具体的用法。

# %%
# Timestamp 上定义了一个 value 属性，其返回的整数值代表了从1970年1月1日零点到给定时间戳相差的纳秒数，请利用这个属性构造一个随机生成给定日期区间内日期序列的函数。
def random_date_series_fixed(start_date, end_date, n):
    # 1. 转换为 Timestamp
    start = pd.Timestamp(start_date)
    end = pd.Timestamp(end_date) + pd.Timedelta(days=1) # 修正逻辑：加一天以包含结束日期当天
    
    # 2. 计算时间差的总秒数（避免纳秒过大溢出，通常秒级精度足够，如果必须纳秒需小心处理）
    # 这里演示保留纳秒精度，但使用 float 随机数避免 randint 溢出
    start_val = start.value
    end_val = end.value
    
    # 使用 uniform 生成 float 类型的随机数，范围在 [start, end)
    # float64 的精度对于纳秒级时间戳可能会丢失极微小的精度，但通常可接受
    random_ts = np.random.uniform(start_val, end_val, n)
    
    # 3. 转回 datetime
    return pd.to_datetime(random_ts.astype(np.int64))

# 测试
print(random_date_series_fixed('2020-1-1', '2020-1-31', 5))
# Out:
# DatetimeIndex(['2020-01-10 02:14:21.979148800',
#                '2020-01-17 08:58:32.016123392',
#                '2020-01-01 04:17:42.863680256',
#                '2020-01-16 15:16:27.827645440',
#                '2020-01-24 09:02:17.453752320'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# 最后，要介绍一种改变序列采样频率的方法`asfreq`，它能够根据指定的`freq`对序列进行类似于`reindex`的操作:

# %%
s = pd.Series(np.random.rand(5),
              index = pd.to_datetime([
                  '2020-1-%d' %i for i in range(1,10,2)
              ]))
s.head()
# Out:
# 2020-01-01    0.747074
# 2020-01-03    0.592786
# 2020-01-05    0.326027
# 2020-01-07    0.262343
# 2020-01-09    0.900865
# dtype: float64

# %%
s.asfreq('D').head()
# Out:
# 2020-01-01    0.747074
# 2020-01-02         NaN
# 2020-01-03    0.592786
# 2020-01-04         NaN
# 2020-01-05    0.326027
# Freq: D, dtype: float64

# %%
s.asfreq('12h').head()
# Out:
# 2020-01-01 00:00:00    0.747074
# 2020-01-01 12:00:00         NaN
# 2020-01-02 00:00:00         NaN
# 2020-01-02 12:00:00         NaN
# 2020-01-03 00:00:00    0.592786
# Freq: 12h, dtype: float64

# %% [markdown]
# 前面提到了`datetime64[ns]`本质上可以理解为一个大整数，对于一个该类型的序列，可以使用`max,min,mean`，来取得最大时间戳，最小时间戳和"平均"时间戳.

# %% [markdown]
# ##### 3.dt对象

# %% [markdown]
# 如同`category, string`的序列上定义了`cat, str`来完成分类数据和文本数据的操作，在时序类型的序列上定义了`dt`对象来完成许多时间序列的相关操作。这里对于`datetime64[ns]`类型而言，可以大致分为三类操作：取出时间相关的属性、判断时间戳是否满足条件、取整操作。

# %% [markdown]
# 第一类操作的常用属性包括:`date,time,year,month,day,hour,minute,second,microsecond,nanosecond,dayofweek,dayofyear,weekofyear,daysinmonth,quarter`,其中`daysinmonth,quarter`分别表示该月一共有几天和季度。

# %%
s = pd.Series(pd.date_range('2020-1-1','2020-1-3', freq = 'D'))
s.dt.date
# Out:
# 0    2020-01-01
# 1    2020-01-02
# 2    2020-01-03
# dtype: object

# %%
s.dt.time
# Out:
# 0    00:00:00
# 1    00:00:00
# 2    00:00:00
# dtype: object

# %%
s.dt.day
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int32

# %%
s.dt.daysinmonth
# Out:
# 0    31
# 1    31
# 2    31
# dtype: int32

# %% [markdown]
# 在这些属性中，经常使用的是`dayofweek`，它返回了周中的星期情况，周一为0，周二为1，依次类推：

# %%
s.dt.dayofweek
# Out:
# 0    2
# 1    3
# 2    4
# dtype: int32

# %% [markdown]
# 此外，可以通过`month_name, day_name`返回英文的月名和星期名，注意它们是方法而不是属性:

# %%
s.dt.month_name()
# Out:
# 0    January
# 1    January
# 2    January
# dtype: object

# %%
s.dt.day_name()
# Out:
# 0    Wednesday
# 1     Thursday
# 2       Friday
# dtype: object

# %% [markdown]
# 第二类判断操作主要用于测试是否为月/季/年的第一天或者最后一天:

# %%
s.dt.is_year_start # 还可选 is_quarter/month_start
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
s.dt.is_year_end # 还可选 is_quarter/month_end
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# 第三类的取整操作包含`round, ceil, floor`，它们的公共参数为`freq`，常用的包括`H, min, S`（小时，分钟，秒），所有可选的`freq`可参考[此处](https://pandas.pydata.org/docs/user_guide/timeseries.html#offset-aliases)

# %%
s = pd.Series(pd.date_range('2020-1-1 20:35:00',
                            '2020-1-1 22:35:00',
                            freq = '45min'))
s
# Out:
# 0   2020-01-01 20:35:00
# 1   2020-01-01 21:20:00
# 2   2020-01-01 22:05:00
# dtype: datetime64[ns]

# %%
s.dt.round('1h')
# Out:
# 0   2020-01-01 21:00:00
# 1   2020-01-01 21:00:00
# 2   2020-01-01 22:00:00
# dtype: datetime64[ns]

# %%
s.dt.ceil('1h')
# Out:
# 0   2020-01-01 21:00:00
# 1   2020-01-01 22:00:00
# 2   2020-01-01 23:00:00
# dtype: datetime64[ns]

# %%
s.dt.floor('1h')
# Out:
# 0   2020-01-01 20:00:00
# 1   2020-01-01 21:00:00
# 2   2020-01-01 22:00:00
# dtype: datetime64[ns]

# %% [markdown]
# ##### 4.时间戳的切片与索引
# 一般而言，时间戳序列作为索引使用。如果想要选出某个子时间戳序列，第一类方法是利用`dt`对象和布尔条件联合使用，另一种方式是利用切片，后者常用于连续时间戳。下面举一些例子说明:

# %%
s = pd.Series(np.random.randint(2,size = 366),
              index = pd.date_range('2020-1-1','2020-12-31'))
idx = pd.Series(s.index).dt
s.head()
# Out:
# 2020-01-01    1
# 2020-01-02    0
# 2020-01-03    1
# 2020-01-04    0
# 2020-01-05    0
# Freq: D, dtype: int32

# %% [markdown]
# Example1：每月的第一天或者最后一天

# %%
s[(idx.is_month_start | idx.is_month_end).values].head()
# Out:
# 2020-01-01    1
# 2020-01-31    1
# 2020-02-01    0
# 2020-02-29    1
# 2020-03-01    1
# dtype: int32

# %% [markdown]
# Example2: 双休日

# %%
s[( (idx.dayofweek == 5) | (idx.dayofweek == 6) ).values].head()
# Out:
# 2020-01-04    0
# 2020-01-05    0
# 2020-01-11    1
# 2020-01-12    0
# 2020-01-18    1
# dtype: int32

# %% [markdown]
# Example3: 取出单日值

# %%
s['2020-01-01']
# Out:
# np.int32(1)

# %%
s['20200101']      # 自动转化格式
# Out:
# np.int32(1)

# %% [markdown]
# Example4: 取出七月

# %%
s['2020-07'].head()
# Out:
# 2020-07-01    1
# 2020-07-02    0
# 2020-07-03    1
# 2020-07-04    1
# 2020-07-05    0
# Freq: D, dtype: int32

# %% [markdown]
# Example5: 取出5月初至7月15日

# %%
s['2020-05':'2020-7-15'].head()
# Out:
# 2020-05-01    1
# 2020-05-02    1
# 2020-05-03    1
# 2020-05-04    0
# 2020-05-05    1
# Freq: D, dtype: int32

# %%
s['2020-05':'2020-7-15'].tail()
# Out:
# 2020-07-11    1
# 2020-07-12    1
# 2020-07-13    0
# 2020-07-14    1
# 2020-07-15    1
# Freq: D, dtype: int32

# %% [markdown]
# #### 三、时间差
# ##### 1.Timedelta的生成
# 正如在第一节中所说，时间差可以理解为两个时间戳的差，这里也可以通过`pd.Timedelta`来构造:

# %%
pd.Timestamp('20200102 08:00:00') - pd.Timestamp('20200101 07:35:00')
# Out:
# Timedelta('1 days 00:25:00')

# %%
pd.Timedelta(days=1, minutes = 25) # 注意需要加s
# Out:
# Timedelta('1 days 00:25:00')

# %%
pd.Timedelta('1 days 25 minutes')  # 字符串生成
# Out:
# Timedelta('1 days 00:25:00')

# %% [markdown]
# 生成时间差序列的主要方式是`pd.to_timedelta`，其类型为`timedelta64[ns]`：

# %%
s = pd.to_timedelta(df.Time_Record)
s.head()
# Out:
# 0   0 days 00:04:34
# 1   0 days 00:04:20
# 2   0 days 00:05:22
# 3   0 days 00:04:08
# 4   0 days 00:05:22
# Name: Time_Record, dtype: timedelta64[ns]

# %% [markdown]
# 与`date_range`一样，时间差序列也可以用`timedelta_range`来生成,它们两者具有一致的参数:

# %%
pd.timedelta_range('0s','1000s', freq = '6min')
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 00:06:00', '0 days 00:12:00'], dtype='timedelta64[ns]', freq='6min')

# %%
pd.timedelta_range('0s','1000s', periods = 3)
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 00:08:20', '0 days 00:16:40'], dtype='timedelta64[ns]', freq=None)

# %% [markdown]
# 对于`Timedelta`序列，同样也定义了`dt`对象，上面主要定义了的属性包括`days,seconds,microseconds,nanoseconds`,它们分别返回了对应的时间差特征。需要注意的是，这里的`seconds`不是指单纯的秒，而是对天数取余后剩余的秒数:

# %%
s.dt.seconds.head()
# Out:
# 0    274
# 1    260
# 2    322
# 3    248
# 4    322
# Name: Time_Record, dtype: int32

# %% [markdown]
# 如果不想对天数取余而直接对应秒数，可以使用`total_seconds`：

# %%
s.dt.total_seconds().head()
# Out:
# 0    274.0
# 1    260.0
# 2    322.0
# 3    248.0
# 4    322.0
# Name: Time_Record, dtype: float64

# %% [markdown]
# 与时间戳序列类似，取整函数也是可以在`dt`对象上使用的:

# %%
pd.to_timedelta(df.Time_Record).dt.round('min').head()
# Out:
# 0   0 days 00:05:00
# 1   0 days 00:04:00
# 2   0 days 00:05:00
# 3   0 days 00:04:00
# 4   0 days 00:05:00
# Name: Time_Record, dtype: timedelta64[ns]

# %% [markdown]
# ##### 2.Timedelta的运算
# 时间差支持的常用运算有三类：与标量的乘法运算、与时间戳的加减法运算、与时间差的加减法与除法运算:

# %%
td1 = pd.Timedelta(days = 1)
td2 = pd.Timedelta(days = 3)
ts = pd.Timestamp('20200101')
td1 * 2
# Out:
# Timedelta('2 days 00:00:00')

# %%
td2 - td1
# Out:
# Timedelta('2 days 00:00:00')

# %%
ts + td1
# Out:
# Timestamp('2020-01-02 00:00:00')

# %%
ts - td1
# Out:
# Timestamp('2019-12-31 00:00:00')

# %% [markdown]
# 这些运算都可以移植到时间差的序列上:

# %%
td1 = pd.timedelta_range(start = '1 days', periods = 5)
td2 = pd.timedelta_range(start = '12 hours', freq = '2h', periods = 5)
ts = pd.date_range('20200101', '20200105')
td1 * 5
# Out:
# TimedeltaIndex(['5 days', '10 days', '15 days', '20 days', '25 days'], dtype='timedelta64[ns]', freq='5D')

# %%
td1 * pd.Series(list(range(5))) # 逐个相乘
# Out:
# 0    0 days
# 1    2 days
# 2    6 days
# 3   12 days
# 4   20 days
# dtype: timedelta64[ns]

# %%
td1 - td2
# Out:
# TimedeltaIndex(['0 days 12:00:00', '1 days 10:00:00', '2 days 08:00:00',
#                 '3 days 06:00:00', '4 days 04:00:00'],
#                dtype='timedelta64[ns]', freq=None)

# %%
td1 + pd.Timestamp('20200101')
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-04', '2020-01-05',
#                '2020-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
td1 + ts # 逐个相加
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-04', '2020-01-06', '2020-01-08',
#                '2020-01-10'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# #### 四、日期偏置
# ##### 1.Offset对象
# 日期偏置是一种和日历相关的特殊时间差，例如回到第一节中的两个问题:如何求2020年9月第一个周一的日期，以及如何求2020年9月7日后的第30个工作日是哪一天。

# %%
pd.Timestamp('20200831') + pd.offsets.WeekOfMonth(week = 0, weekday = 0)
# Out:
# Timestamp('2020-09-07 00:00:00')

# %%
pd.Timestamp('20200907') + pd.offsets.BDay(30)
# Out:
# Timestamp('2020-10-19 00:00:00')

# %% [markdown]
# 从上面的例子中可以看到，`Offset`对象在`pd.offsets`中被定义。当使用`+`时获取离其最近的下一个日期，当使用`-`时获取离其最近的上一个日期:

# %%
pd.Timestamp('20200831') - pd.offsets.WeekOfMonth(week = 0, weekday = 0)
# Out:
# Timestamp('2020-08-03 00:00:00')

# %%
pd.Timestamp('20200907') - pd.offsets.BDay(30)
# Out:
# Timestamp('2020-07-27 00:00:00')

# %%
pd.Timestamp('20200907') + pd.offsets.MonthEnd()
# Out:
# Timestamp('2020-09-30 00:00:00')

# %% [markdown]
# 常用的日期偏置如下可以查阅这里的[文档](https://pandas.pydata.org/docs/user_guide/timeseries.html#dateoffset-objects)描述。在文档罗列的`Offset`中，需要介绍一个特殊的`Offset`对象`CDay`,其中的`holidays,weekmask`参数能够分别对自定义的日期和星期进行过滤，前者传入了需要过滤的日期列表，后者传入的是三个字母的星期缩写构成的星期字符串，其作用是只保留字符串中出现的星期:

# %%
my_filter = pd.offsets.CDay(n=1,weekmask='Wed Fri',holidays = ['20200109'])
dr = pd.date_range('20200108','20200111')
dr.to_series().dt.dayofweek
# Out:
# 2020-01-08    2
# 2020-01-09    3
# 2020-01-10    4
# 2020-01-11    5
# Freq: D, dtype: int32

# %%
[i + my_filter for i in dr]
# Out:
# [Timestamp('2020-01-10 00:00:00'),
#  Timestamp('2020-01-10 00:00:00'),
#  Timestamp('2020-01-15 00:00:00'),
#  Timestamp('2020-01-15 00:00:00')]

# %% [markdown]
# 上面的例子中， `n` 表示增加一天 `CDay` ， `dr` 中的第一天为 `20200108` ，但由于下一天 `20200109` 被排除了，并且 `20200110` 是合法的周五，因此转为 `20200110` ，其他后面的日期处理类似。

# %% [markdown]
# ##### 2.偏置字符串
# 前面提到了关于`date_range`的`freq`取值可用`Offset`对象，同时在`pandas`中几乎每一个`Offset`对象绑定了日期偏置字符串(`frequencies strings/offset aliases`),可以指定`Offset`对应的字符串来替代使用。下面举一些常见的例子。

# %%
pd.date_range('20200101','20200331', freq = 'MS') # 月初
# Out:
# DatetimeIndex(['2020-01-01', '2020-02-01', '2020-03-01'], dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range('20200101','20200331', freq = 'ME') # 月末
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31'], dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range('20200101','20200110', freq = 'B') # 工作日
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range('20200101','20200201', freq = 'W-MON')  # 周一
# Out:
# DatetimeIndex(['2020-01-06', '2020-01-13', '2020-01-20', '2020-01-27'], dtype='datetime64[ns]', freq='W-MON')

# %%
pd.date_range('20200101','20200201', freq = 'WOM-1MON')  # 每月第一个周一
# Out:
# DatetimeIndex(['2020-01-06'], dtype='datetime64[ns]', freq='WOM-1MON')

# %% [markdown]
# 上面的这些字符串，等价于使用如下的`Offset`对象:

# %%
pd.date_range('20200101','20200331', freq = pd.offsets.MonthBegin()) # 月初
# Out:
# DatetimeIndex(['2020-01-01', '2020-02-01', '2020-03-01'], dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range('20200101','20200331', freq = pd.offsets.MonthEnd()) # 月末
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31'], dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range('20200101','20200110', freq = pd.offsets.BDay()) # 工作日
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range('20200101','20200201', freq = pd.offsets.CDay(weekmask = 'Mon')) # 每周一
# Out:
# DatetimeIndex(['2020-01-06', '2020-01-13', '2020-01-20', '2020-01-27'], dtype='datetime64[ns]', freq='C')

# %%
pd.date_range('20200101','20200201', freq = pd.offsets.WeekOfMonth(week = 0 ,weekday = 0)) # 每月第一个周一
# Out:
# DatetimeIndex(['2020-01-06'], dtype='datetime64[ns]', freq='WOM-1MON')

# %% [markdown]
# 如果对时区处理的时间偏置有兴趣了解讨论，可以参考[这里](https://github.com/pandas-dev/pandas/pull/36516)的讨论

# %% [markdown]
# #### 五、时序中的滑窗与分组
# ##### 1.滑动窗口
# 所谓时序的滑窗函数，即把滑动窗口用`freq`关键词代替，下面给出一个具体的应用案例：在股票市场中有一个指标为`BOLL`指标，它由中轨线、上轨线、下轨线这三根线构成，具体的计算方法分别是`N`日均值线、`N`日均值加两倍`N`日标准差线、`N`日均值减两倍`N`日标准差线。利用`rolling`对象计算`N=30`的`BOLL`指标可以如下写出:

# %%
import matplotlib.pyplot as plt
idx= pd.date_range('20200101','20201231', freq = 'B')
np.random.seed(2020)
data = np.random.randint(-1,2,len(idx)).cumsum() # 随机游动构造模拟序列
s = pd.Series(data, index = idx)
s.head()
# Out:
# 2020-01-01   -1
# 2020-01-02   -2
# 2020-01-03   -1
# 2020-01-06   -1
# 2020-01-07   -2
# Freq: B, dtype: int64

# %%
r = s.rolling(window = '30D') # 30天滚动窗口
plt.plot(s)
plt.title('BOLL LINES')
plt.plot(r.mean())
plt.plot(r.mean() + 2 * r.std())
plt.plot(r.mean() - 2 * r.std())

# %% [markdown]
# 对于`shift`函数而言，作用在`datatime64`为索引的序列上时，可以指定`freq`单位进行滑动:

# %%
s.shift(freq = '50D').head()
# Out:
# 2020-02-20   -1
# 2020-02-21   -2
# 2020-02-22   -1
# 2020-02-25   -1
# 2020-02-26   -2
# dtype: int64

# %% [markdown]
# 另外，`datetime64[ns]`的序列进行`diff`后就能够得到`timedelta64[ns]`的序列，这能够使用户方便地观察有序时间序列的间隔:

# %%
my_series = pd.Series(s.index)
my_series.head()
# Out:
# 0   2020-01-01
# 1   2020-01-02
# 2   2020-01-03
# 3   2020-01-06
# 4   2020-01-07
# dtype: datetime64[ns]

# %%
my_series.diff(1).head()
# Out:
# 0      NaT
# 1   1 days
# 2   1 days
# 3   3 days
# 4   1 days
# dtype: timedelta64[ns]

# %% [markdown]
# ##### 2.重采样
# 重采样对象`resample`和第四章中分组对象`groupby`的用法类似，前者是针对时间序列的分组计算而设计的分组对象。
# 例如，对上面的序列计算每10天的均值:

# %%
s.resample('10D').mean().head()
# Out:
# 2020-01-01   -2.000000
# 2020-01-11   -3.166667
# 2020-01-21   -3.625000
# 2020-01-31   -4.000000
# 2020-02-10   -0.375000
# Freq: 10D, dtype: float64

# %% [markdown]
# 同时，如果没有内置定义的处理函数，可以通过`apply`方法自定义:

# %%
s.resample('10D').apply(lambda x: x.max() - x.min()).head() # 极差
# Out:
# 2020-01-01    3
# 2020-01-11    4
# 2020-01-21    4
# 2020-01-31    2
# 2020-02-10    4
# Freq: 10D, dtype: int64

# %% [markdown]
# 在`resample`中要特别注意组边界值的处理情况，默认情况下起始值的计算方法是从最小值时间戳对应的日期午夜`00:00:00`开始增加`freq`，直到不超过该最小时间戳的最大时间戳，由此对应的时间戳为起始值，然后每次累加`freq`参数作为分割点进行分组，区间情况为左闭右开。下面构造一个不均匀的例子:

# %%
idx = pd.date_range('20200101 8:26:35','20200101 9:31:58', freq = '77s')
data = np.random.randint(-1,2,len(idx)).cumsum()
s = pd.Series(data, index = idx)
s.head()
# Out:
# 2020-01-01 08:26:35   -1
# 2020-01-01 08:27:52   -1
# 2020-01-01 08:29:09   -2
# 2020-01-01 08:30:26   -3
# 2020-01-01 08:31:43   -4
# Freq: 77s, dtype: int64

# %% [markdown]
# 下面对应的第一个组起始值为`08:24:00`,其是从当天0点增加72个`freq = 7min`得到的，如果再增加一个`freq`则超出了序列的最小时间戳`08:26:35`:

# %%
s.resample('7min').mean().head()
# Out:
# 2020-01-01 08:24:00   -1.750000
# 2020-01-01 08:31:00   -2.600000
# 2020-01-01 08:38:00   -2.166667
# 2020-01-01 08:45:00    0.200000
# 2020-01-01 08:52:00    2.833333
# Freq: 7min, dtype: float64

# %% [markdown]
# 有时候，用户希望从序列的最小时间戳开始依次增加`freq`进行分组，此时可以指定`origin`参数为`start`：

# %%
s.resample('7min',origin = 'start').mean().head()
# Out:
# 2020-01-01 08:26:35   -2.333333
# 2020-01-01 08:33:35   -2.400000
# 2020-01-01 08:40:35   -1.333333
# 2020-01-01 08:47:35    1.200000
# 2020-01-01 08:54:35    3.166667
# Freq: 7min, dtype: float64

# %% [markdown]
# 在返回值中，要注意索引一般是取组的第一个时间戳，但`ME,A,Q,BM,BA,BQ,W`这七个是取对应区间的最后一个时间戳:

# %%
s = pd.Series(np.random.randint(2,size = 366),
              index = pd.date_range('2020-01-01','2020-12-31'))
s.resample('ME').mean().head()
# Out:
# 2020-01-31    0.451613
# 2020-02-29    0.448276
# 2020-03-31    0.516129
# 2020-04-30    0.566667
# 2020-05-31    0.451613
# Freq: ME, dtype: float64

# %%
s.resample('MS').mean().head() # 结果一样，但索引不同
# Out:
# 2020-01-01    0.451613
# 2020-02-01    0.448276
# 2020-03-01    0.516129
# 2020-04-01    0.566667
# 2020-05-01    0.451613
# Freq: MS, dtype: float64

# %% [markdown]
# #### 六、练习
# ##### Ex1: 太阳辐射数据集
# 现有一份关于太阳辐射的数据集:

# %%
df = pd.read_csv('solar.csv',usecols = ['Date','Time','Radiation','Temperature'])
df.head()
# Out:
#                     Date      Time  Radiation  Temperature
# 0  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 1  9/29/2016 12:00:00 AM  23:50:23       1.21           48
# 2  9/29/2016 12:00:00 AM  23:45:26       1.23           48
# 3  9/29/2016 12:00:00 AM  23:40:21       1.21           48
# 4  9/29/2016 12:00:00 AM  23:35:24       1.17           48

# %%
# 1.将Datetime,Time合并为一个时间列Datetime，同时把它作为索引后排序。
date = df['Date'].str.extract(r'([/\w]+)\s.+')[0]
df['Datetime'] = pd.to_datetime(date + ' ' + df['Time'])
df = df.drop(columns = ['Date','Time']).set_index('Datetime').sort_index()
df.head()
# Out:
#                      Radiation  Temperature
# Datetime
# 2016-09-01 00:00:08       2.58           51
# 2016-09-01 00:05:10       2.83           51
# 2016-09-01 00:20:06       2.16           51
# 2016-09-01 00:25:05       2.21           51
# 2016-09-01 00:30:09       2.25           51

# %%
# 2.每条记录时间的间隔显然并不一致，请解决如下问题:
# a.找出间隔时间的前三个最大值所对应的三组时间戳。
s = df.index.to_series().reset_index(drop=True).diff().dt.total_seconds()
max_3 = s.nlargest(3).index
df.index[max_3.union(max_3 - 1)]
# Out:
# DatetimeIndex(['2016-09-29 23:55:26', '2016-10-01 00:00:19',
#                '2016-11-29 19:05:02', '2016-12-01 00:00:02',
#                '2016-12-05 20:45:53', '2016-12-08 11:10:42'],
#               dtype='datetime64[ns]', name='Datetime', freq=None)

# %%
# b.是否存在一个大致的范围，使得绝大多数的间隔时间都落在这个区间中？如果存在，请对此范围内的样本间隔秒数画出柱状图，设置`bins=50`。
res = s.mask((s>s.quantile(0.99))|(s<s.quantile(0.01)))
_ = plt.hist(res,bins =50)

# %%
# 3.求如下指标对应的Series:
# a.温度与辐射量的6小时滑动相关系数
res = df.Radiation.rolling('6h').corr(df.Temperature)
res.tail(3)
# Out:
# Datetime
# 2016-12-31 23:45:04    0.328574
# 2016-12-31 23:50:03    0.261883
# 2016-12-31 23:55:01    0.262406
# dtype: float64

# %%
# b 以三点，九点，十五点，二十一点为分割，该观测所在时间区间的温度均值序列
res = df.Temperature.resample('6h',origin = '03:00').mean()
res.head(3)
# Out:
# Datetime
# 2016-08-31 21:00:00    51.218750
# 2016-09-01 03:00:00    50.033333
# 2016-09-01 09:00:00    59.379310
# Freq: 6h, Name: Temperature, dtype: float64

# %%
# c.每个观测6小时前的辐射量(一般而言不会恰好取到，此时取最近时间戳对应的辐射量)
my_dt = df.index.shift(freq = '-6h')
int_loc = [df.index.get_indexer([i],method='nearest')[0] for i in my_dt]
int_loc = np.array(int_loc).reshape(-1)
res = df.Radiation.iloc[int_loc]
res.index = df.index
res.tail(3)
# Out:
# Datetime
# 2016-12-31 23:45:04    9.33
# 2016-12-31 23:50:03    8.49
# 2016-12-31 23:55:01    5.84
# Name: Radiation, dtype: float64

# %% [markdown]
# ##### Ex2:水果销量数据集
# 现有一份2019年每日水果销量记录表:

# %%
# 1.统计如下指标
# a.每月上半月(15号及之前)与下半月(16号及之后)葡萄销量的比值
df = pd.read_csv('fruit.csv')
df.Date = pd.to_datetime(df.Date)
df_grape = df.query("Fruit == 'Grape'")
res = df_grape.groupby([np.where(df_grape.Date.dt.day <=15,'First','Second'),
                        df_grape.Date.dt.month])['Sale'].mean().to_frame().unstack(0).droplevel(0,axis=1)
res = (res.First/res.Second).rename_axis('Month')
res.head()
# Out:
# Month
# 1    1.174998
# 2    0.968890
# 3    0.951351
# 4    1.020797
# 5    0.931061
# dtype: float64

# %%
# b.每月最后一天的生梨销量总和
df[df.Date.dt.is_month_end].query("Fruit == 'Pear'").groupby(df.Date).Sale.sum().head()
# Out:
# Date
# 2019-01-31    847
# 2019-02-28    774
# 2019-03-31    761
# 2019-04-30    648
# 2019-05-31    616
# Name: Sale, dtype: int64

# %%
# c.每月最后一天工作日的生梨销量总和
df[df.Date.isin(pd.date_range('20190101','20191231',freq = 'BME'))].query("Fruit == 'Pear'").groupby('Date').Sale.mean().head()
# Out:
# Date
# 2019-01-31    60.500000
# 2019-02-28    59.538462
# 2019-03-29    56.666667
# 2019-04-30    64.800000
# 2019-05-31    61.600000
# Name: Sale, dtype: float64

# %%
# d.每月最后五天的苹果销量均值
target_dt = df.drop_duplicates().groupby(df.Date.drop_duplicates().dt.month)['Date'].nlargest(5).reset_index(drop=True)
res = df.set_index('Date').loc[target_dt].reset_index().query("Fruit == 'Apple'")
res = res.groupby(res.Date.dt.month)['Sale'].mean().rename_axis('Month')
res.head()
# Out:
# Month
# 1    65.313725
# 2    54.061538
# 3    59.325581
# 4    65.795455
# 5    57.465116
# Name: Sale, dtype: float64

# %%
# 2.按月计算周一至周日各品种水果的平均记录条数，行索引外层为水果名称，内层为月份，列索引为星期。
month_order = ['January','February','March','April','May','June','July','August','September','October','November','December']
week_order = ['Mon','Tue','Wed','Thu','Fri','Sat','Sum']
group1 = df.Date.dt.month_name().astype('category').cat.reorder_categories(month_order, ordered=True)
group2 = df.Fruit
group3 = df.Date.dt.dayofweek.replace(dict(zip(range(7),week_order))).astype('category').cat.reorder_categories(week_order, ordered=True)
res = df.groupby([group1, group2,group3])['Sale'].count().to_frame().unstack(0).droplevel(0,axis=1)
res.head()
# Out:
# C:\Users\24153\AppData\Local\Temp\ipykernel_23180\1496894943.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   res = df.groupby([group1, group2,group3])['Sale'].count().to_frame().unstack(0).droplevel(0,axis=1)
# Date        January  February  March  April  May  June  July  August  \
# Fruit Date
# Apple Mon        46        43     43     47   43    40    41      38
#       Tue        50        40     44     52   46    39    50      42
#       Wed        50        47     37     43   39    39    58      43
#       Thu        45        35     31     47   58    33    52      44
#       Fri        32        33     52     31   46    38    37      48
#
# Date        September  October  November  December
# Fruit Date
# Apple Mon          59       42        39        45
#       Tue          40       57        47        47
#       Wed          35       46        47        38
#       Thu          36       63        37        40
#       Fri          34       37        46        41

# %%
# 3.按天计算向前10个工作日窗口的苹果销量均值序列，非工作日的值用上一个工作日的结果填充。
df_apple = df[(df.Fruit=='Apple')&(~df.Date.dt.dayofweek.isin([5,6]))]
s = pd.Series(df_apple.Sale.values,index=df_apple.Date).groupby('Date').sum()
res = s.rolling('10D').mean().reindex(pd.date_range('20190101','20191231')).fillna(method='ffill')
res.head()
# Out:
# C:\Users\24153\AppData\Local\Temp\ipykernel_23180\3567759012.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   res = s.rolling('10D').mean().reindex(pd.date_range('20190101','20191231')).fillna(method='ffill')
# 2019-01-01    189.000000
# 2019-01-02    335.500000
# 2019-01-03    520.333333
# 2019-01-04    527.750000
# 2019-01-05    527.750000
# Freq: D, dtype: float64
